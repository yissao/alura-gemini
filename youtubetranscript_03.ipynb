# %%
pip install youtube-transcript-api
# %pip -q install google-genai
# Out:
# Collecting youtube-transcript-api
#   Downloading youtube_transcript_api-1.0.3-py3-none-any.whl.metadata (23 kB)
# Requirement already satisfied: defusedxml<0.8.0,>=0.7.1 in /usr/local/lib/python3.11/dist-packages (from youtube-transcript-api) (0.7.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from youtube-transcript-api) (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->youtube-transcript-api) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->youtube-transcript-api) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->youtube-transcript-api) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->youtube-transcript-api) (2025.4.26)
# Downloading youtube_transcript_api-1.0.3-py3-none-any.whl (2.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 32.3 MB/s eta 0:00:00
# Installing collected packages: youtube-transcript-api
# Successfully installed youtube-transcript-api-1.0.3

# %%
import re
from youtube_transcript_api import YouTubeTranscriptApi

# Solicita a URL do vídeo
url = input("Cole o link do vídeo do YouTube: ")

# Expressão regular para encontrar o ID do vídeo
padrao = r"(?:v=|\/)([0-9A-Za-z_-]{11}).*"

# Aplica o regex
match = re.search(padrao, url)

if match:
    video_id = match.group(1)
    print(f"ID do vídeo: {video_id}")
else:
    print("URL inválida ou ID não encontrado.")
# video_id = "PldyIefUPOg"

try:
    transcript_list = YouTubeTranscriptApi.list_transcripts(video_id)

    # Busca a transcrição gerada automaticamente em português
    transcript = transcript_list.find_generated_transcript(['pt'])

    # O resultado é um FetchedTranscript com .snippets
    data = transcript.fetch()

    # Itera corretamente sobre os FetchedTranscriptSnippet
    # for entry in data.snippets:
        # print(f"{entry.start:.2f}s: {entry.text}")

except Exception as e:
    print(f"Erro: {e}")

full_text = " ".join([entry.text for entry in data.snippets])
print(full_text)
# Out:
# Cole o link do vídeo do YouTube: https://youtu.be/_CzMiNTDLMI
# ID do vídeo: _CzMiNTDLMI
# Ufa! Chegamos no último dia da nossa imersão de A da Lura com Google. Eu sou Fabrício Carraro. Tô aqui como sempre com o querido Luciano Martins, com a querida Valquíria Alencar paraa nossa quinta e mais importante, mais relevante, mais popular. Tá na mídia aí, né? Tá nas tendências. O hype de nome de agentes de IA. Mais divertida. É, então, provavelmente é mais divertida, eu acho. Para quem é deve, com certeza mais divertida. E para quem não é deve, eu acho que também. Porque a gente vai mostrar aqui todo o poder dos agentes de inteligência artificial. O que você que trabalha com marketing, que trabalha com finanças, que trabalha com advocacia, vai poder fazer com o poder dos agentes, você próprio, né? você usando aí um pouquinho de código com o que você aprendeu na live intermediária, com o que você aprendeu ontem, na quarta aula lá que a gente começou a mexer com os chatbots e com o que você vai aprender hoje aqui na quinta aula de [Música] agentes. Mas pra gente começar essa aula aqui, antes disso, só quero dar alguns recadinhos. Beleza. O primeiro é, lembra que ontem eu falei que já tava aberto o enunciado, né, para você começar a criar o seu projeto. Continua aberto, na verdade, né? Então, só relembrando rapidinho, você tem até sábado às 23:59 para fazer, para entregar o projeto. Vai ter um formulário aqui embaixo ou também lá no guia de mergulho também no seu e-mail que você vai poder enviar, preencher esse formulário ali entre o sábado à meia-noite, né? entre sexa e sábado ali à meia-noite até às 23:59 do próprio sábado. Você vai entrar lá no formulário, botar o seu nome, e-mail e o link do GitHub com o seu projeto completo. E aí no domingo entre a meia-noite e às 23:59 vocês vão poder votar nos melhores projetos lá no Discord e os 30 melhores vão vir pra gente, pra banca aqui do nosso da nossa imersão para serem avaliados e a gente vai dar o resultado dos vencedores do projeto lá na segunda-feira na live de encerramento às 6:30 da tarde, onde a gente também vai falar de outras coisas, falar do mundo da IA. Mas na segunda-feira, além dessa live, vocês também vão ter acesso ali a uma condição especial para assinar a Lura. Então, como a gente sempre fala, não assine a Lura agora, hoje não pense nisso por enquanto, né? Faça aula com a gente, vai dormir, vai fazer o seu projetinho até o sábado às 23:59 e espera que na segunda-feira você vai receber um e-mail, vai receber no grupo de WhatsApp, vai receber no Discord da imersão essa condição especial para finalmente assinar a Lura e poder fazer aqui os cursos, as formações da Escola de Inteligência Artificial, da Escola de Ciência de Dados, da Escola de Front End, back end, de gestão e inovação, enfim, qualquer coisa você assina e você tem acesso a 100% da plataforma. forma, sem mais delongas, vamos começar aqui só dando uma microrisão, né, que você a gente tá no Google Estúdio, como sempre, você para essa aula você também vai precisar da IPI, né, a chave da P que a gente explicou no final da aula 3, a gente explicou no começo da aula 4. Revisando, você vai aqui em get API ke ou no dashboard, você vai entrar aqui nesse botão de criar chave de API. E aí você, se não tiver nenhum projeto, você vai, ele já vai criar sozinho. Se você já tiver projeto, você vai selecionar algum e ele vai criar uma chave de API para você, que ela vai ficar disponível aqui embaixo. E como sempre, a IP aqui, ela vai fazer a conexão lá diretamente com o collab, mas hoje vai ser um pouquinho diferente. A gente não vai abrir um collab do zero como a gente fez na última aula. A gente vai passar para vocês um collabo. Por quê? Ele é um colab que tem muita parte de código, então que a gente a gente quer fazer que ele seja mais acessível, tanto para você que já é dev, que já sabe programar, para entender o framework de agentes do Google, né, que eu imagino que você talvez não tenha usado ainda. E até para você que não é programador ou não é programadora, que vai talvez se perderia muito em tanto código que ...

# %%
# Configura a API Key do Google Gemini

import os
from google.colab import userdata

os.environ["GOOGLE_API_KEY"] = userdata.get('GOOGLE_API_KEY')

# %%
#=========================================================
from google import genai
from IPython.display import HTML, Markdown

cliente = genai.Client()
#=========================================================
modelo = 'gemini-2.0-flash'
#=========================================================
# resposta = cliente.models.generate_content(model=modelo, contents="quantas pessoas foram a Lua?")
# # print(resposta.result) #erro AttributeError: 'GenerateContentResponse' object has no attribute 'result'
# print(resposta)
# #=========================================================
# print(resposta.text)

from google.genai import types

chat_config = types.GenerateContentConfig(
    system_instruction ="""
    Objetivo: Anotações para estudo
    Instruções: A seguir está a transcrição de um vídeo do YouTube.
    ⚠️ Atenção: a transcrição foi gerada automaticamente e pode conter erros de pontuação, palavras trocadas ou trechos desconexos.
    Sua tarefa é:
    Corrigir os trechos mal transcritos com base no contexto geral do vídeo.
    Organizar a informação em parágrafos coesos e claros.
    Produzir um resumo detalhado, destacando os principais tópicos abordados, exemplos dados, argumentos utilizados e qualquer conclusão relevante.
    Separe os termos técnicos e faça uma explicação breve deles
    Se possível, identifique o público-alvo ou a intenção do vídeo.
    """,
    temperature=0.5
)
chat=cliente.chats.create(model=modelo, config=chat_config)
resposta = chat.send_message(full_text)
display(Markdown(f"Resposta:\n {resposta.text}"))
# Out:
# Resposta:
#  ## Resumo Detalhado da Imersão Alura com Google: Agentes de IA
#
# O vídeo é a transcrição da quinta e última aula da imersão Alura com Google sobre Inteligência Artificial (IA), focada em agentes de IA. Os instrutores Fabrício Carraro, Luciano Martins e Valquíria Alencar guiam os participantes na criação de um sistema multiagentes para geração de posts para redes sociais, utilizando o Agent Development Kit (ADK) do Google.
#
# **Público-alvo:** Desenvolvedores e profissionais de diversas áreas (marketing, finanças, advocacia, etc.) interessados em utilizar agentes de IA para automatizar tarefas e otimizar processos.
#
# **Intenção do vídeo:** Apresentar o poder dos agentes de IA e capacitar os participantes a criarem seus próprios sistemas multiagentes, utilizando o ADK do Google.
#
# ### Recados Iniciais
#
# *   **Projeto Final:** Os participantes têm até sábado às 23:59 para entregar seus projetos. O formulário de envio estará disponível até o mesmo horário.
# *   **Votação:** No domingo, a comunidade poderá votar nos melhores projetos no Discord.
# *   **Premiação:** Os 30 melhores projetos serão avaliados por uma banca, e os vencedores serão anunciados na live de encerramento na segunda-feira.
# *   **Condição Especial Alura:** Na segunda-feira, os participantes terão acesso a uma condição especial para assinar a Alura.
#
# ### Preparação do Ambiente
#
# *   **Google Colab:** A aula utiliza um Colab pré-configurado para facilitar o aprendizado, especialmente para quem não tem experiência com programação.
# *   **Chave da API:** É necessário obter e configurar a chave da API do Google AI Studio para conectar o Colab aos serviços de IA do Google.
# *   **Instalação do Google Gen AI:** Instalação da biblioteca do Google para utilizar o Gemini.
#
# ### Conexão com a Busca do Google
#
# *   **Exemplo Prático:** Os instrutores demonstram como conectar o Gemini com a busca do Google para obter informações atualizadas sobre a próxima imersão da Alura.
# *   **Código:** Eles explicam o código necessário para realizar a busca, utilizando o parâmetro `tools` na configuração da requisição ao Gemini.
#
# ### Introdução aos Agentes de IA
#
# *   **O que são Agentes:** Agentes são sistemas que automatizam uma sequência de ações para resolver um problema específico, permitindo a criação de "esteiras de ações" personalizadas.
# *   **Framework ADK:** O Agent Development Kit (ADK) do Google é um framework que simplifica a criação e orquestração de agentes de IA.
# *   **Vantagens do ADK:** O ADK facilita a sincronização entre diferentes agentes e a estruturação das etapas do processo de resolução de um problema.
# *   **Sistemas Multiagentes:** São compostos por vários agentes especializados em tarefas específicas, com um agente orquestrador que coordena o fluxo de informações entre eles.
#
# ### Criação de um Sistema Multiagentes para Instagram
#
# *   **Projeto:** O objetivo é criar um sistema que gera posts para o Instagram a partir de notícias recentes sobre um determinado tópico.
# *   **Agentes:** O sistema é composto por quatro agentes:
#     *   **Buscador:** Busca notícias no Google sobre um tópico específico, limitando os resultados a um mês.
#     *   **Planejador:** Analisa as notícias encontradas, identifica os pontos mais relevantes e decide qual delas tem maior potencial de engajamento.
#     *   **Redator:** Escreve um rascunho de post para o Instagram com base no plano gerado pelo agente planejador.
#     *   **Revisor:** Revisa o rascunho do post, verificando clareza, concisão, correção e tom de escrita.
# *   **Implementação:** Os instrutores guiam os participantes na implementação de cada agente, explicando o código necessário e as configurações específicas.
# *   **Instruções (Prompts):** Eles enfatizam a importância de definir instruções claras e precisas para cada agente, utilizando técnicas de engenharia de prompt.
# *   **Testes e Ajustes:** Os instrutores demonstram como testar o sistema e ajustar os prompts para obter melhores resultados.
#
# ### Considerações Finais
#
# *   **Criatividade:** Os instrutores incentivam os participantes a serem criativos e a adaptarem o sistema apresentado para seus próprios casos de uso.
# *   **Human-in-the-Loop:** Eles recomendam que haja sempre um humano no processo de geração de conteúdo, para garantir a qualidade e a adequação do material.
# *   **Próximos Passos:** Os participantes são encorajados a explorar a documentação do ADK e a experimentar com diferentes configurações e agentes.
#
# ### Termos Técnicos Explicados
#
# *   **Framework:** Conjunto de ferramentas e bibliotecas que facilitam o desenvolvimento de software.
# *   **ADK (Agent Development Kit):** Kit de desenvolvimento de agentes do Google.
# *   **Multiagentes:** Sistema composto por vários agentes de IA que trabalham em conjunto para resolver um problema.
# *   **Orquestração:** Coordenação e gerenciamento do fluxo de informações entre os agentes.
# *   **LLM (Large Language Model):** Modelo de linguagem grande, como o Gemini, capaz de gerar texto, traduzir idiomas e responder a perguntas.
# *   **API (Application Programming Interface):** Interface que permite a comunicação entre diferentes softwares.
# *   **Prompt:** Instrução ou pergunta enviada a um modelo de linguagem para obter uma resposta.
# *   **Engenharia de Prompt:** Técnica de criação de prompts eficazes para obter os resultados desejados de um modelo de linguagem.
# *   **Tool:** Ferramenta que um agente pode utilizar para realizar uma tarefa específica, como a busca no Google.
# *   **System Instruction:** Instruções que definem o papel e o comportamento de um agente.
#
# ### Observações
#
# *   O vídeo demonstra de forma prática e acessível como criar um sistema multiagentes utilizando o ADK do Google.
# *   Os instrutores fornecem explicações claras e exemplos relevantes para facilitar o aprendizado.
# *   O vídeo incentiva a experimentação e a criatividade, permitindo que os participantes adaptem o sistema apresentado para seus próprios casos de uso.
# *   A transcrição automática pode conter erros, mas o resumo detalhado busca corrigir e organizar as informações para garantir a compreensão do conteúdo.
